# %%
import cv2
import time
import numpy as np
from yolo import YOLO
from PIL import Image
import matplotlib as plt

# %%
#-------------------------------------#
#       对单张图片进行预测
#-------------------------------------#
def detect_image(image_path):
    print('Start detect!')
    yolo = YOLO()
    try:
        image = Image.open(image_path)
#         image.show()
    except:
        print('Open Error! Try again!')
        pass
    else:
        r_image = yolo.detect_image(image)
        r_image.show()
#         r_image.save(image_path.split('.')[0] + '_result.png')
    print('Finish detect!')

# %%
detect_image(r'F:\盲道图片测试结果\40.PNG')
# Out:
# Start detect!
# Loading pretrained weights.
# Finish loading!
# model_data/yolov4_maskdetect_weights1.pth model, anchors, and classes loaded.
# Open Error! Try again!
# Finish detect!

# %%
detect_image(r'G:\MaskDetect-YOLOv4-2\125.jpeg')
# Out:
# Start detect!
# Loading pretrained weights.
# Finish loading!
# model_data/yolov4_coco_pretrained_weights.pth model, anchors, and classes loaded.
# (1, 4)
# b'roadblock: 0.73'
# Finish detect!

# %%
plt.imshow()

# %%
print(num_mask)
# Out:
# 0

# %%
import os
dir_name = r"D:\xiaozurenwu\MaskDetect-YOLOv4-PyTorch-master\test10"
list_dir = os.listdir(dir_name)
for i in list_dir:
    print('Start detect!')
    yolo = YOLO()
    image_path = r"D:\xiaozurenwu\MaskDetect-YOLOv4-PyTorch-master\test10\train_1.jpg"
    try:
        image = Image.open(r"D:\xiaozurenwu\MaskDetect-YOLOv4-PyTorch-master\test10\train_1.jpg")
    except:
        print('Open Error! Try again!')
        pass
    else:
        r_image = yolo.detect_image(image)
        r_image.save(image_path.split('.')[0] + '_result.png')
    print('Finish detect!')
# Out:
# Start detect!
# Loading pretrained weights.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-b222b974180a> in <module>
#       4 for i in list_dir:
#       5     print('Start detect!')
# ----> 6     yolo = YOLO()
#       7     image_path = r"D:\xiaozurenwu\MaskDetect-YOLOv4-PyTorch-master\test10\train_1.jpg"
#       8     try:
#
# G:\MaskDetect-YOLOv4-PyTorch-master\yolo.py in __init__(self, **kwargs)
#      39         self.class_names = self._get_class()
#      40         self.anchors = self._get_anchors()
# ---> 41         self.generate()
#      42     #---------------------------------------------------#
#      43     #   获得所有的分类
#
# G:\MaskDetect-YOLOv4-PyTorch-master\yolo.py in generate(self)
#      74         model_dict = self.net.state_dict()
#      75         pretrained_dict = torch.load(self.model_path)
# ...

# %%
#-------------------------------------#
#       对一段视频进行检测
#-------------------------------------#
def detect_video(video_path):
    print('Start detect!')
    yolo = YOLO()
    capture = cv2.VideoCapture(video_path)
    writer = None
    fps = 0.0
    while True:
        t1 = time.time()
        # 读取某一帧
        grabbed, frame = capture.read()
        if not grabbed:
            break
        # opencv读取的是BGR，格式转变，BGRtoRGB
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        # 转变成Image
        frame = Image.fromarray(np.uint8(frame))
        # 进行检测
        frame = np.array(yolo.detect_image(frame))
        # RGBtoBGR满足opencv显示格式
        frame = cv2.cvtColor(frame,cv2.COLOR_RGB2BGR)

        fps  = (fps + (1. / (time.time() - t1))) / 2
        print("FPS: %.2f" % (fps))
        frame = cv2.putText(frame, "FPS: %.2f" % (fps), (0, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)
        
        if writer is None:
            fourcc = cv2.VideoWriter_fourcc(*'MP4V')
            writer = cv2.VideoWriter(video_path.split('.')[0] + '_result.mp4', fourcc, 30, (frame.shape[1], frame.shape[0]), True)
        writer.write(frame)
    writer.release()
    capture.release()
    print('Finish detect!')
detect_video("test6.mp4")
# Out:
# Start detect!
# Loading pretrained weights.
# Finish loading!
# model_data/yolov4_maskdetect_weights1.pth model, anchors, and classes loaded.
# (5, 4)
# b'nomask: 0.99'
# b'nomask: 0.98'
# b'nomask: 0.98'
# b'nomask: 0.97'
# b'nomask: 0.90'
# people_num: 5
# mask_num: 0
# nomask_num: 5
# FPS: 1.74
# (5, 4)
# b'nomask: 0.99'
# b'nomask: 0.98'
# b'nomask: 0.98'
# b'nomask: 0.97'
# b'nomask: 0.90'
# people_num: 5
# mask_num: 0
# nomask_num: 5
# FPS: 2.77
# (5, 4)
# b'nomask: 0.99'
# b'nomask: 0.98'
# b'nomask: 0.98'
# b'nomask: 0.97'
# b'nomask: 0.90'
# people_num: 5
# mask_num: 0
# nomask_num: 5
# FPS: 3.38
# (5, 4)
# b'nomask: 0.99'
# b'nomask: 0.98'
# b'nomask: 0.98'
# b'nomask: 0.97'
# b'nomask: 0.90'
# people_num: 5
# mask_num: 0
# nomask_num: 5
# FPS: 3.75
# (5, 4)
# b'nomask: 0.99'
# b'nomask: 0.98'
# b'nomask: 0.98'
# b'nomask: 0.97'
# b'nomask: 0.90'
# people_num: 5
# mask_num: 0
# nomask_num: 5
# FPS: 3.88
# (5, 4)
# b'nomask: 0.99'
# b'nomask: 0.98'
# b'nomask: 0.98'
# ...

# %%
#-------------------------------------#
#       对一段视频进行检测
#-------------------------------------#
def detect_video1(video_path):
    print('Start detect!')
    yolo = YOLO()
    capture = cv2.VideoCapture(video_path)
    writer = None
    fps = 0.0
    while True:
        t1 = time.time()
        # 读取某一帧
        grabbed, frame = capture.read()
        if not grabbed:
            break
        # opencv读取的是BGR，格式转变，BGRtoRGB
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        # 转变成Image
        frame = Image.fromarray(np.uint8(frame))
        # 进行检测
        frame = np.array(yolo.detect_image(frame))
        # RGBtoBGR满足opencv显示格式
        frame = cv2.cvtColor(frame,cv2.COLOR_RGB2BGR)

        fps  = (fps + (1. / (time.time() - t1))) / 2
        print("FPS: %.2f" % (fps))
        frame = cv2.putText(frame, "FPS: %.2f" % (fps), (0, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)
        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cv2.destroyAllWindows()
    capture.release()
    print('Finish detect!')

# %%
import os
import av
import numpy as np
import tellopy
import cv2
#import FaceMaskDetection.api as face
#import MSCNN.api as mscnn
import matplotlib.pyplot as plt
import threading

# %%
#-------------------------------------#
#       对一段视频进行检测
#-------------------------------------#
def detect_video1(video_path):
    print('Start detect!')
    yolo = YOLO()
    capture = cv2.VideoCapture(video_path)
    writer = None
    fps = 0.0
    while True:
        t1 = time.time()
        # 读取某一帧
        grabbed, frame = capture.read()
        if not grabbed:
            break
        # opencv读取的是BGR，格式转变，BGRtoRGB
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        # 转变成Image
        frame = Image.fromarray(np.uint8(frame))
        # 进行检测
        frame = np.array(yolo.detect_image(frame))
        # RGBtoBGR满足opencv显示格式
        frame = cv2.cvtColor(frame,cv2.COLOR_RGB2BGR)

        fps  = (fps + (1. / (time.time() - t1))) / 2
        print("FPS: %.2f" % (fps))
        frame = cv2.putText(frame, "FPS: %.2f" % (fps), (0, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)
        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cv2.destroyAllWindows()
    capture.release()
    print('Finish detect!')
detect_video1(0)
# Out:
# Start detect!
# Loading pretrained weights.
# Finish loading!
# model_data/yolov4_maskdetect_weights1.pth model, anchors, and classes loaded.
# (1, 4)
# b'nomask: 0.92'
# people_num: 1
# mask_num: 0
# nomask_num: 1
# FPS: 0.95
# (1, 4)
# b'nomask: 0.93'
# people_num: 1
# mask_num: 0
# nomask_num: 1
# FPS: 4.16
# (1, 4)
# b'nomask: 0.88'
# people_num: 1
# mask_num: 0
# nomask_num: 1
# FPS: 6.03
# (1, 4)
# b'nomask: 0.86'
# people_num: 1
# mask_num: 0
# nomask_num: 1
# FPS: 6.93
# (1, 4)
# b'nomask: 0.88'
# people_num: 1
# mask_num: 0
# nomask_num: 1
# FPS: 7.42
# (1, 4)
# b'nomask: 0.80'
# people_num: 1
# mask_num: 0
# nomask_num: 1
# FPS: 7.66
# (1, 4)
# b'nomask: 0.76'
# people_num: 1
# mask_num: 0
# nomask_num: 1
# FPS: 7.84
# (1, 4)
# b'nomask: 0.88'
# people_num: 1
# mask_num: 0
# nomask_num: 1
# FPS: 7.90
# (1, 4)
# b'nomask: 0.91'
# people_num: 1
# mask_num: 0
# nomask_num: 1
# FPS: 7.96
# (1, 4)
# b'nomask: 0.93'
# people_num: 1
# mask_num: 0
# nomask_num: 1
# FPS: 7.93
# ...

# %%
"""
Stream test:
Pull the video from the drone and display in cv2 window.
Optionally encode video and dump to file.
@author Saksham Sinha and Jonathan Byrne
@copyright 2018 see license file for details
"""
import os
import av
import numpy as np
import tellopy
import cv2
#import FaceMaskDetection.api as face
#import MSCNN.api as mscnn
import matplotlib.pyplot as plt
import threading


def encode(frame, ovstream, output):
    """
    convert frames to packets and write to file
    """
    try:
        pkt = ovstream.encode(frame)
    except Exception as err:
        print("encoding failed{0}".format(err))

    if pkt is not None:
        try:
            output.mux(pkt)
        except Exception:
            print('mux failed: ' + str(pkt))
    return True


def main():
    FACE_MASK = False
    CLEAN = False
    ATTN = False
    def ct_thread():
        result = mscnn.infer(image)
        print(result)

    def at_thread():
        os.system('python3.6 atten.py')
    # Set up tello streaming
    drone = tellopy.Tello()
    # drone.log.set_level(2)
    drone.connect()
    drone.start_video()

    # container for processing the packets into frames
    container = av.open(drone.get_video_stream())
    video_st = container.streams.video[0]

    # stream and outputfile for video
    output = av.open('archive.mp4', 'w')
    ovstream = output.add_stream('mpeg4', video_st.rate)
    ovstream.pix_fmt = 'yuv420p'
    ovstream.width = video_st.width
    ovstream.height = video_st.height

    for packet in container.demux((video_st,)):
        for frame in packet.decode():
            # convert frame to cv2 image and show
            image = cv2.cvtColor(np.array(
                frame.to_image()), cv2.COLOR_RGB2BGR)


            key = cv2.waitKey(1) & 0xFF
            if key == ord('a'):
                FACE_MASK = not FACE_MASK

            if key == ord('s'):
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                output_info, img_output = face.inference(image, draw_result=True, target_shape=(260, 260))
                plt.imshow(img_output)
                plt.imsave('result/mask.png', img_output)
                plt.show()
            if key == ord('c'):
                CLEAN = not CLEAN
            if key == ord('g'):
                ATTN = not ATTN
            if key == ord('t'):
                os.system('python3.6 tello_test.py')

            if key == ord('p'):
                b, g, r = cv2.split(image)
                image = cv2.merge([r, g, b])
                plt.imsave('result/cap.png', image)

#             if FACE_MASK:  # 开启面部识别
#                 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#                 output_info, img_output = face.inference(image, draw_result=True, target_shape=(260, 260))
#                 image = np.float32(img_output) / 256.
#                 b, g, r = cv2.split(image)
#                 image = cv2.merge([r, g, b])
#             plt.imshow(img_output)
#             plt.show()
#             FACE_MASK = False

            cv2.imshow('frame', image)

#             if CLEAN:  # 密度分析
#                 print('------dense------')

#                 ct = threading.Thread(target=ct_thread)
#                 ct.start()
#                 CLEAN = False

#             if ATTN:
#                 print('-------route-------')
#                 at = threading.Thread(target=at_thread)
#                 at.start()
#                 ATTN = False
#             # time.sleep(1)



if __name__ == '__main__':
    main()
# Out:
# Tello: 21:55:16.418:  Info: start video thread
# Tello: 21:55:16.420:  Info: send connection request (cmd="conn_req:9617")
# Tello: 21:55:16.420:  Info: video receive buffer size = 524288
# Tello: 21:55:16.420:  Info: state transit State::disconnected -> State::connecting
# Tello: 21:55:16.420:  Info: start video (cmd=0x25 seq=0x01e4)
# Tello: 21:55:16.421:  Info: get video stream
# Tello: 21:55:16.421:  Info: start video (cmd=0x25 seq=0x01e4)
# Tello: 21:55:16.453:  Info: connected. (port=9617)
# Tello: 21:55:16.455:  Info: send_time (cmd=0x46 seq=0x01e4)
# Tello: 21:55:16.455:  Info: state transit State::connecting -> State::connected
# Tello: 21:55:16.455:  Info: VideoStream.handle_event(CONNECTED)
# Tello: 21:55:16.455:  Info: recv: ack: cmd=0x34 seq=0x0000 cc 60 00 27 90 34 00 00 00 00 72 a5
# Tello: 21:55:16.456:  Info: recv: ack: cmd=0x20 seq=0x0000 cc 60 00 27 b0 20 00 00 00 00 42 b9
# ...

# %%
pip install tellopy -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python tello.py
# Out:
# Traceback (most recent call last):
#   File "tello.py", line 5, in <module>
#     import libh264decoder
# ModuleNotFoundError: No module named 'libh264decoder'

# %%
# !where python
# Out:
# D:\anaconda3\envs\pytorch1\python.exe
# c:\Python27\python.exe
